# %%
import json
import pandas as pd

branches_file = "branches.json"

# %%
with open(branches_file, "r") as f:
    branches = json.load(f)

df = pd.DataFrame(branches)

df["region"].unique()
# Out:
# array(['Asia Pacific', 'North America', 'Africa'], dtype=object)
